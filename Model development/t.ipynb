# %%
import transformers

print("Version:", transformers.__version__)
print("File:", transformers.__file__)
# Out:
# Version: 4.55.4
# File: e:\projects\Depi\New folder\F1\New folder\venv\Lib\site-packages\transformers\__init__.py
